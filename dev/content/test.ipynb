# %% [markdown]
# # Matplotlib Example
#
# In this notebook, we will create a simple example using Matplotlib to plot a sine wave. Matplotlib is a widely used library for creating visualizations in Python.

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/echarles/micromamba/envs/datalayer/lib/python3.11/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/echarles/micromamba/envs/datalayer/lib/python3.11/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/echarles/micromamba/envs/datalayer/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/echarles/micromamba/envs/datalayer/lib/python3.11/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/echarles/micromamba/envs/datalayer/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/echarles/micromamba/envs/datalayer/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/echarles/micromamba/envs/datalayer/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/echarles/micromamba/envs/datalayer/lib/python3.11/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/echarles/micromamba/envs/datalayer/lib/python3.11/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/echarles/micromamba/envs/datalayer/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/echarles/micromamba/envs/datalayer/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data for the sine wave
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

# Create the plot
plt.figure(figsize=(10, 5))
plt.plot(x, y, label='Sine Wave', color='blue')
plt.title('Sine Wave Example')
plt.xlabel('X-axis (radians)')
plt.ylabel('Y-axis (amplitude)')
plt.axhline(0, color='black',linewidth=0.5, ls='--')
plt.axvline(0, color='black',linewidth=0.5, ls='--')
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.legend()
plt.show()
